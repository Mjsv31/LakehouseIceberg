# %% [markdown]
# # Capa gold - Carga inicial

# %% [markdown]
# ## Variables

# %%
# %run ../00-Modulos/n_modulo_variables.ipynb
# Out:
# Servicios:
#  Warehouse  = s3a://iceberg/warehouse
#  EndPoint   = http://localhost:9000
#  Uri        = thrift://localhost:9083
# Base de Datos Landing =  iceberg.landing
# Base de Datos Bronze  =  iceberg.bronze
# Base de Datos Silver  =  iceberg.silver
# Base de Datos Gold    =  iceberg.gold
# Rutas:
#  Raiz    = dbfs:/Capacitacion/Spark/Databricks/
#  Landing = P001_MJSV1/zDatos/landing/
#  Bronze  = P001_MJSV1/zDatos/bronze/
#  Silver  = P001_MJSV1/zDatos/silver/
#  Gold    = P001_MJSV1/zDatos/gold/
# Base de Datos Landing =  P001_MJSV1_LANDING
# Base de Datos Bronze  =  P001_MJSV1_BRONZE
# Base de Datos Silver  =  P001_MJSV1_SILVER
# Base de Datos Gold    =  P001_MJSV1_GOLD

# %% [markdown]
# ## SparkSession

# %%
spark = spark_session_hive("Lakehouse-Iceberg")

# %% [markdown]
# ## Dimension de Tiempo

# %% [markdown]
# ### Extracción

# %%
# - Obtiene dataframe de la capa landing
df_DimDates = spark.read.table(f'{vSchemaLand}.dim_dates')

# %% [markdown]
# ### Carga

# %%
# - Reemplaza la información en la capa gold
df_DimDates.writeTo(f'{vSchemaGold}.dim_dates').overwritePartitions()

# %% [markdown]
# ## Cierre de SparkSession

# %%
stop_session(spark)
# Out:
# Sesión de Spark cerrada correctamente.
