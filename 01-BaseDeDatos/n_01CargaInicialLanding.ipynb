# %% [markdown]
# # Capa landing - Carga inicial

# %% [markdown]
# ## Variables

# %%
# %run ../00-Modulos/n_modulo_variables.ipynb
# Out:
# Servicios:
#  Warehouse  = s3a://iceberg/warehouse
#  EndPoint   = http://localhost:9000
#  Uri        = thrift://localhost:9083
# Base de Datos Landing =  iceberg.landing
# Base de Datos Bronze  =  iceberg.bronze
# Base de Datos Silver  =  iceberg.silver
# Base de Datos Gold    =  iceberg.gold

# %% [markdown]
# ## SparkSession

# %%
spark = spark_session_hive("Lakehouse-Iceberg")

# %% [markdown]
# ## Crea schema y tablas landing

# %%
# - Mensaje
print("")
print("Crea schema landing")
# Out:
# Crea schema landing

# %%
# - Crea el schema si no existe
spark.sql(f"""
CREATE SCHEMA IF NOT EXISTS {vSchemaLand}
LOCATION "{vWarehouse}/landing"
""")
# Out:
# DataFrame[]

# %% [markdown]
# ## Funciones

# %%
# - Funcion que realiza la carga inicial de archivos parquet
# - en la capa landing
def fGeneraParquet(pArchivo):

    # -- Procesa archivos de minio
    vPath = f'{vData}/{pArchivo}'

    # -- Mensaje a pantalla
    print("")
    print(f'Ingestando archivo {pArchivo}')
    print("")

    # -- Genera dataframe a partir del archivo descargado
    df_archivo = spark.read.parquet(vPath)

    # -- Genera el nombre de la tabla
    vTable = os.path.splitext(pArchivo)[0].upper()
    
    # -- Escribe archivo parquet en capa landing
    df_archivo.writeTo(f'{vSchemaLand}.{vTable}').using("iceberg").createOrReplace()

# %% [markdown]
# ## Ingesta archivos parquet

# %%
#  -- Lista de archivos a cargar
vArchivos = [
    'customers.parquet',
    'dealerships.parquet',
    'employees.parquet',
    'payments.parquet',
    'products.parquet',
    'products_costs.parquet',
    'promotions.parquet',
    'salaries.parquet',
    'sales_transactions.parquet',
    'dim_dates.parquet'
    ]

# Por cada archivo invoca a la funcion fGeneraParquet
for Archivo in vArchivos:
    fGeneraParquet(Archivo)
# Out:
# Ingestando archivo customers.parquet
#
#
# Ingestando archivo dealerships.parquet
#
#
# Ingestando archivo employees.parquet
#
#
# Ingestando archivo payments.parquet
#
#
# Ingestando archivo products.parquet
#
#
# Ingestando archivo products_costs.parquet
#
#
# Ingestando archivo promotions.parquet
#
#
# Ingestando archivo salaries.parquet
#
#
# Ingestando archivo sales_transactions.parquet
#
#
# Ingestando archivo dim_dates.parquet
