# %% [markdown]
# # Capa Bronze - Catálogo de Salarios

# %% [markdown]
# ## Librerias

# %%
from pyspark.sql import functions as f

# %% [markdown]
# ## Variables

# %%
# %run ../00-Modulos/n_modulo_variables.ipynb
# Out:
# Servicios:
#  Warehouse  = s3a://directiceberg/warehouse
#  EndPoint   = http://localhost:9000
#  Uri        = jdbc:mariadb://localhost:3307/metastore_iceberg
# Base de Datos Landing =  minio.landing
# Base de Datos Bronze  =  minio.bronze
# Base de Datos Silver  =  minio.silver
# Base de Datos Gold    =  minio.gold

# %% [markdown]
# ## Spark Session

# %%
spark = spark_session("Lakehouse-Iceberg")

# %% [markdown]
# ## Extracción

# %%
df_salaries = spark.read.table(f'{vSchemaLand}.salaries')

# %% [markdown]
# ## Carga

# %%
df_salaries.writeTo(f'{vSchemaBron}.salaries').overwrite(f.lit(True))

# %% [markdown]
# ## Cierre de SparkSession

# %%
stop_session(spark)
# Out:
# Sesión de Spark cerrada correctamente.
